# %% [markdown]
# Математическая библиотека Python SymPy

# %%
import sympy
sympy.__version__
# Out:
# '1.14.0'

# %%
import sympy, math

print(sympy.sqrt(7))
print(math.sqrt(12))
print(sympy.sqrt(12))
# Out:
# sqrt(7)
# 3.4641016151377544
# 2*sqrt(3)

# %%
from sympy import *
x = Symbol('x')
expr = integrate(x**x, x)
expr
# Out:
# Integral(x**x, x)

# %%
from sympy import *
x = Symbol('x')
x = 7
sqrt(x)
# Out:
# sqrt(7)
